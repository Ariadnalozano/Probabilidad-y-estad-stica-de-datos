# %% [markdown]
# # Lectura de datos

# %%
import pandas as pd

# %%
df = pd.read_csv("ETF prices.csv")
df.head()
# Out:
#   fund_symbol  price_date   open   high    low  close  adj_close  volume
# 0         AAA  2020-09-09  25.10  25.12  25.07  25.07      24.85   17300
# 1         AAA  2020-09-10  25.06  25.07  25.05  25.07      24.85   23500
# 2         AAA  2020-09-11  25.04  25.05  25.02  25.03      24.81   33400
# 3         AAA  2020-09-14  25.01  25.06  25.01  25.02      24.80   13100
# 4         AAA  2020-09-15  25.02  25.03  25.01  25.01      24.79   12100

# %%
df["adj_close"].max(), df["adj_close"].mean()
# Out:
# (2808750080.0, 119657.87353138486)

# %%
df.iloc[5] # ingreso por renglones
# Out:
# fund_symbol           AAA
# price_date     2020-09-16
# open                24.97
# high                24.98
# low                 24.97
# close               24.97
# adj_close           24.75
# volume              14100
# Name: 5, dtype: object

# %%
df.describe()
# Out:
#                open          high           low         close     adj_close  \
# count  3.866030e+06  3.866030e+06  3.866030e+06  3.866030e+06  3.866030e+06
# mean   1.202537e+05  1.262811e+05  1.149734e+05  1.196726e+05  1.196579e+05
# std    1.149917e+07  1.208270e+07  1.097204e+07  1.143655e+07  1.143655e+07
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.486000e+01  2.494000e+01  2.476000e+01  2.485000e+01  2.229000e+01
# 50%    3.388000e+01  3.406000e+01  3.368000e+01  3.387000e+01  3.108000e+01
# 75%    5.417000e+01  5.441000e+01  5.390000e+01  5.416000e+01  5.007000e+01
# max    2.656750e+09  2.808750e+09  2.609750e+09  2.808750e+09  2.808750e+09
#
#              volume
# count  3.866030e+06
# mean   1.026745e+06
# std    1.275733e+07
# min    0.000000e+00
# 25%    3.553000e+03
# 50%    2.133900e+04
# 75%    1.269000e+05
# max    2.987062e+09

# %%
import yfinance as yf
data = yf.download("SPY AAPL", start="2017-01-01", end="2017-04-30")
data
# Out:
# [*********************100%***********************]  2 of 2 completed
#             Adj Close                  Close                   High  \
#                  AAPL         SPY       AAPL         SPY       AAPL
# Date
# 2017-01-03  27.219831  203.788025  29.037500  225.240005  29.082500
# 2017-01-04  27.189362  205.000397  29.004999  226.580002  29.127501
# 2017-01-05  27.327635  204.837570  29.152500  226.399994  29.215000
# 2017-01-06  27.632296  205.570404  29.477501  227.210007  29.540001
# 2017-01-09  27.885387  204.891876  29.747499  226.460007  29.857500
# ...               ...         ...        ...         ...        ...
# 2017-04-24  33.808071  215.515350  35.910000  237.169998  35.987499
# 2017-04-25  34.017548  216.769363  36.132500  238.550003  36.224998
# 2017-04-26  33.817486  216.633041  35.919998  238.399994  36.150002
# 2017-04-27  33.843388  216.814819  35.947498  238.600006  36.040001
# 2017-04-28  33.810429  216.342270  35.912498  238.080002  36.075001
#
# ...
